# %% [markdown]
# RAIN - Real & Artificial Intelligence for Neuroscience
#
# ## Geometric analysis
# - This notebook will take the position.csv files (created using `2-Prepare_positions` notebook) and process them using geometric criteria (distance, angle and overall movement).
#
# #### Requirements:
# - The position.csv files.
# - Geometric thresholds for exploration and freezing (see below).

# %% [markdown]
# ---
# #### Load the necessary modules

# %%
import os
import rainstorm.geometric_analysis as rst

# %% [markdown]
# ---
# #### 1. State your project path
# All we need to define is the path to the same folder we used in `2-Prepare_positions`, and the path to the parameters file (which contains the thresholds for the geometric analysis).

# %%
base = r'C:\Users\dhers\Desktop\RAINSTORM'
folder_path = os.path.join(base, r'docs\examples\NOR_example')
params = os.path.join(folder_path, 'params.yaml')

# %% [markdown]
# ---
# #### 2. We can open an example file and see what is inside

# %%
example_path = rst.choose_example_csv(params, look_for = 'TS')

# Plot mouse exploration around multiple targets
rst.plot_position(params, example_path)
# Out:
# Plotting coordinates from NOR_TS_C1_A_position.csv

# %% [markdown]
# The plot shows the position of each target, along with the nose tracked and colored according to the angle of approach towards them.
#
# The geometric method labels exploration events when the nose is both colored (heading towards the target) and inside the dashed line (close to the target).

# %% [markdown]
# ---
# #### 3. We can use the positions to measure time spent in each of the drawn ROIs.

# %%
roi_activity = rst.detect_roi_activity(params, example_path, plot_activity=True)
# Out:
# No ROIs found in the parameters file. Skipping ROI activity analysis.

# %%
rst.plot_heatmap(params, example_path)

# %% [markdown]
# ---
# #### 4.  We can also measure other behaviours, such as freezing

# %%
# Plot freezing events
rst.plot_freezing(params, example_path)

# %% [markdown]
# The plot shows the movement of the mouse over time, shading over freezing events.
#
# By setting a freezing threshold (which we can modify in the params file), we can quantify the time the mouse spent freezing.

# %% [markdown]
# ---
# #### 5. Finally, we can analyze the position files and create:
# - A movement.csv file containing distance traveled, roi activity, and freezing events.
# - A geolabels.csv file with the exploration of each object, frame by frame.

# %%
# Analyze all files in the folder
rst.create_movement_and_geolabels(params)
# Out:
# NOR_Hab_C1_A_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C1_A_movement.csv
# NOR_Hab_C1_B_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C1_B_movement.csv
# NOR_Hab_C1_C_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C1_C_movement.csv
# NOR_Hab_C1_D_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C1_D_movement.csv
# NOR_Hab_C2_A_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C2_A_movement.csv
# NOR_Hab_C2_B_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C2_B_movement.csv
# NOR_Hab_C2_C_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C2_C_movement.csv
# NOR_Hab_C2_D_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C2_D_movement.csv
# NOR_Hab_C3_A_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C3_A_movement.csv
# NOR_Hab_C3_B_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C3_B_movement.csv
# NOR_Hab_C3_C_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C3_C_movement.csv
# NOR_Hab_C3_D_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C3_D_movement.csv
# NOR_Hab_C4_A_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C4_A_movement.csv
# NOR_Hab_C4_B_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C4_B_movement.csv
# NOR_Hab_C4_C_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C4_C_movement.csv
# NOR_Hab_C4_D_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C4_D_movement.csv
# NOR_Hab_C5_A_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C5_A_movement.csv
# NOR_Hab_C5_B_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C5_B_movement.csv
# NOR_Hab_C5_C_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C5_C_movement.csv
# NOR_Hab_C5_D_position.csv is missing targets: obj_1, obj_2
# Saved movement to NOR_Hab_C5_D_movement.csv
# Saved geolabels to NOR_TR_C1_A_geolabels.csv
# Saved movement to NOR_TR_C1_A_movement.csv
# Saved geolabels to NOR_TR_C1_B_geolabels.csv
# Saved movement to NOR_TR_C1_B_movement.csv
# Saved geolabels to NOR_TR_C1_C_geolabels.csv
# Saved movement to NOR_TR_C1_C_movement.csv
# Saved geolabels to NOR_TR_C1_D_geolabels.csv
# Saved movement to NOR_TR_C1_D_movement.csv
# Saved geolabels to NOR_TR_C2_A_geolabels.csv
# Saved movement to NOR_TR_C2_A_movement.csv
# Saved geolabels to NOR_TR_C2_B_geolabels.csv
# Saved movement to NOR_TR_C2_B_movement.csv
# Saved geolabels to NOR_TR_C2_C_geolabels.csv
# Saved movement to NOR_TR_C2_C_movement.csv
# Saved geolabels to NOR_TR_C2_D_geolabels.csv
# Saved movement to NOR_TR_C2_D_movement.csv
# Saved geolabels to NOR_TR_C3_A_geolabels.csv
# Saved movement to NOR_TR_C3_A_movement.csv
# Saved geolabels to NOR_TR_C3_B_geolabels.csv
# Saved movement to NOR_TR_C3_B_movement.csv
# Saved geolabels to NOR_TR_C3_C_geolabels.csv
# Saved movement to NOR_TR_C3_C_movement.csv
# Saved geolabels to NOR_TR_C3_D_geolabels.csv
# Saved movement to NOR_TR_C3_D_movement.csv
# Saved geolabels to NOR_TR_C4_A_geolabels.csv
# Saved movement to NOR_TR_C4_A_movement.csv
# Saved geolabels to NOR_TR_C4_B_geolabels.csv
# Saved movement to NOR_TR_C4_B_movement.csv
# Saved geolabels to NOR_TR_C4_C_geolabels.csv
# Saved movement to NOR_TR_C4_C_movement.csv
# Saved geolabels to NOR_TR_C4_D_geolabels.csv
# Saved movement to NOR_TR_C4_D_movement.csv
# Saved geolabels to NOR_TR_C5_A_geolabels.csv
# Saved movement to NOR_TR_C5_A_movement.csv
# Saved geolabels to NOR_TR_C5_B_geolabels.csv
# Saved movement to NOR_TR_C5_B_movement.csv
# Saved geolabels to NOR_TR_C5_C_geolabels.csv
# Saved movement to NOR_TR_C5_C_movement.csv
# Saved geolabels to NOR_TR_C5_D_geolabels.csv
# Saved movement to NOR_TR_C5_D_movement.csv
# Saved geolabels to NOR_TS_C1_A_geolabels.csv
# Saved movement to NOR_TS_C1_A_movement.csv
# Saved geolabels to NOR_TS_C1_B_geolabels.csv
# Saved movement to NOR_TS_C1_B_movement.csv
# Saved geolabels to NOR_TS_C1_C_geolabels.csv
# Saved movement to NOR_TS_C1_C_movement.csv
# Saved geolabels to NOR_TS_C1_D_geolabels.csv
# Saved movement to NOR_TS_C1_D_movement.csv
# Saved geolabels to NOR_TS_C2_A_geolabels.csv
# Saved movement to NOR_TS_C2_A_movement.csv
# Saved geolabels to NOR_TS_C2_B_geolabels.csv
# Saved movement to NOR_TS_C2_B_movement.csv
# Saved geolabels to NOR_TS_C2_C_geolabels.csv
# Saved movement to NOR_TS_C2_C_movement.csv
# Saved geolabels to NOR_TS_C2_D_geolabels.csv
# Saved movement to NOR_TS_C2_D_movement.csv
# Saved geolabels to NOR_TS_C3_A_geolabels.csv
# Saved movement to NOR_TS_C3_A_movement.csv
# Saved geolabels to NOR_TS_C3_B_geolabels.csv
# Saved movement to NOR_TS_C3_B_movement.csv
# Saved geolabels to NOR_TS_C3_C_geolabels.csv
# Saved movement to NOR_TS_C3_C_movement.csv
# Saved geolabels to NOR_TS_C3_D_geolabels.csv
# Saved movement to NOR_TS_C3_D_movement.csv
# Saved geolabels to NOR_TS_C4_A_geolabels.csv
# Saved movement to NOR_TS_C4_A_movement.csv
# Saved geolabels to NOR_TS_C4_B_geolabels.csv
# Saved movement to NOR_TS_C4_B_movement.csv
# Saved geolabels to NOR_TS_C4_C_geolabels.csv
# Saved movement to NOR_TS_C4_C_movement.csv
# Saved geolabels to NOR_TS_C4_D_geolabels.csv
# Saved movement to NOR_TS_C4_D_movement.csv
# Saved geolabels to NOR_TS_C5_A_geolabels.csv
# Saved movement to NOR_TS_C5_A_movement.csv
# Saved geolabels to NOR_TS_C5_B_geolabels.csv
# Saved movement to NOR_TS_C5_B_movement.csv
# Saved geolabels to NOR_TS_C5_C_geolabels.csv
# Saved movement to NOR_TS_C5_C_movement.csv
# Saved geolabels to NOR_TS_C5_D_geolabels.csv
# Saved movement to NOR_TS_C5_D_movement.csv

# %% [markdown]
# ---
# ---
# #### Two new csv files were created for each video, one for exploration geolabels and the other for movement related scores.
# We can:
# - Move on to the next notebook to create an artificial neural network that labels exploratory behavior, ` 4-Create_models`.
# - Loose all patience, go straight to ` 6-Seize_labels` and use the geolabels to plot the results of the experiment.
#
# ---
# RAINSTORM - Created on Oct 26, 2023 - @author: Santiago D'hers
