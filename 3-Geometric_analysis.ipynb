# %% [markdown]
# RAIN - Real & Artificial Intelligence for Neuroscience
#
# ## Geometric analysis
# - This notebook will take the position.csv files (created using `2-Prepare_positions` notebook) and process them using geometric criteria (distance, angle and overall movement).
#
# #### Requirements:
# - The position.csv files.
# - Geometric thresholds for exploration and freezing (see below).

# %% [markdown]
# ---
# #### Load the necessary modules

# %%
import os
import rainstorm.geometric_analysis as rst

# %% [markdown]
# ---
# #### 1. State your project path
# You need to define the path to the same folder used in `2-Prepare_positions`, and the path to the parameters file (which contains the thresholds for the geometric analysis).

# %%
base = r'C:\Users\dhers\Desktop\RAINSTORM'
folder_path = os.path.join(base, r'docs\examples\SP_example')
params = os.path.join(folder_path, 'params.yaml')

# %% [markdown]
# ---
# #### 2. We can open an example file and see what is inside

# %%
example_path = rst.choose_example_csv(params, look_for = 'TS')

# Plot mouse exploration around multiple targets
rst.plot_position(params, example_path)
# Out:
# No files found with the specified word
# Plotting coordinates from social_R03_TR3_position.csv

# %% [markdown]
# The plot shows the position of each target, along with the nose tracked and colored according to the angle of approach towards them.
#
# The geometric method labels exploration events when the nose is both colored (heading towards the target) and inside the dashed line (close to the target).

# %% [markdown]
# ---
# #### 3. We can use the positions to measure time spent in each of the drawn ROIs.

# %%
roi_activity = rst.detect_roi_activity(params, example_path, plot_activity=True)

# %%
rst.plot_heatmap(params, example_path)

# %% [markdown]
# ---
# #### 4.  We can also measure other behaviours, such as freezing

# %%
# Plot freezing events
rst.plot_freezing(params, example_path)

# %% [markdown]
# The plot shows the movement of the mouse over time, shading over freezing events.
#
# By setting a freezing threshold (which we can modify in the params file), we can quantify the time the mouse spent freezing.

# %% [markdown]
# ---
# #### 5. Finally, we can analyze the position files and create:
# - A movement.csv file containing distance traveled, roi activity, and freezing events.
# - A geolabels.csv file with the exploration of each object, frame by frame.

# %%
# Analyze all files in the folder
rst.create_movement_and_geolabels(params)
# Out:
# Saved geolabels to social_R01_Hab_geolabels.csv
# Saved movement to social_R01_Hab_movement.csv
# Saved geolabels to social_R02_Hab_geolabels.csv
# Saved movement to social_R02_Hab_movement.csv
# Saved geolabels to social_R03_Hab_geolabels.csv
# Saved movement to social_R03_Hab_movement.csv
# Saved geolabels to social_R04_Hab_geolabels.csv
# Saved movement to social_R04_Hab_movement.csv
# Saved geolabels to social_R05_Hab_geolabels.csv
# Saved movement to social_R05_Hab_movement.csv
# Saved geolabels to social_R06_Hab_geolabels.csv
# Saved movement to social_R06_Hab_movement.csv
# Saved geolabels to social_R07_Hab_geolabels.csv
# Saved movement to social_R07_Hab_movement.csv
# Saved geolabels to social_R08_Hab_geolabels.csv
# Saved movement to social_R08_Hab_movement.csv
# Saved geolabels to social_R09_Hab_geolabels.csv
# Saved movement to social_R09_Hab_movement.csv
# Saved geolabels to social_R10_Hab_geolabels.csv
# Saved movement to social_R10_Hab_movement.csv
# Saved geolabels to social_R11_Hab_geolabels.csv
# Saved movement to social_R11_Hab_movement.csv
# Saved geolabels to social_R12_Hab_geolabels.csv
# Saved movement to social_R12_Hab_movement.csv
# Saved geolabels to social_R13_Hab_geolabels.csv
# Saved movement to social_R13_Hab_movement.csv
# Saved geolabels to social_R14_Hab_geolabels.csv
# Saved movement to social_R14_Hab_movement.csv
# Saved geolabels to social_R15_Hab_geolabels.csv
# Saved movement to social_R15_Hab_movement.csv
# Saved geolabels to social_R16_Hab_geolabels.csv
# Saved movement to social_R16_Hab_movement.csv
# Saved geolabels to social_R17_Hab_geolabels.csv
# Saved movement to social_R17_Hab_movement.csv
# Saved geolabels to social_R18_Hab_geolabels.csv
# Saved movement to social_R18_Hab_movement.csv
# Saved geolabels to social_R19_Hab_geolabels.csv
# Saved movement to social_R19_Hab_movement.csv
# Saved geolabels to social_R20_Hab_geolabels.csv
# Saved movement to social_R20_Hab_movement.csv
# Saved geolabels to social_R21_Hab_geolabels.csv
# Saved movement to social_R21_Hab_movement.csv
# Saved geolabels to social_R22_Hab_geolabels.csv
# Saved movement to social_R22_Hab_movement.csv
# Saved geolabels to social_R23_Hab_geolabels.csv
# Saved movement to social_R23_Hab_movement.csv
# Saved geolabels to social_R01_TR1_geolabels.csv
# Saved movement to social_R01_TR1_movement.csv
# Saved geolabels to social_R02_TR1_geolabels.csv
# Saved movement to social_R02_TR1_movement.csv
# Saved geolabels to social_R03_TR1_geolabels.csv
# Saved movement to social_R03_TR1_movement.csv
# Saved geolabels to social_R04_TR1_geolabels.csv
# Saved movement to social_R04_TR1_movement.csv
# Saved geolabels to social_R05_TR1_geolabels.csv
# Saved movement to social_R05_TR1_movement.csv
# Saved geolabels to social_R06_TR1_geolabels.csv
# Saved movement to social_R06_TR1_movement.csv
# Saved geolabels to social_R07_TR1_geolabels.csv
# Saved movement to social_R07_TR1_movement.csv
# Saved geolabels to social_R08_TR1_geolabels.csv
# Saved movement to social_R08_TR1_movement.csv
# Saved geolabels to social_R09_TR1_geolabels.csv
# Saved movement to social_R09_TR1_movement.csv
# Saved geolabels to social_R10_TR1_geolabels.csv
# Saved movement to social_R10_TR1_movement.csv
# Saved geolabels to social_R11_TR1_geolabels.csv
# Saved movement to social_R11_TR1_movement.csv
# Saved geolabels to social_R12_TR1_geolabels.csv
# Saved movement to social_R12_TR1_movement.csv
# Saved geolabels to social_R13_TR1_geolabels.csv
# Saved movement to social_R13_TR1_movement.csv
# Saved geolabels to social_R14_TR1_geolabels.csv
# Saved movement to social_R14_TR1_movement.csv
# Saved geolabels to social_R15_TR1_geolabels.csv
# Saved movement to social_R15_TR1_movement.csv
# Saved geolabels to social_R16_TR1_geolabels.csv
# Saved movement to social_R16_TR1_movement.csv
# Saved geolabels to social_R17_TR1_geolabels.csv
# Saved movement to social_R17_TR1_movement.csv
# Saved geolabels to social_R18_TR1_geolabels.csv
# Saved movement to social_R18_TR1_movement.csv
# Saved geolabels to social_R19_TR1_geolabels.csv
# Saved movement to social_R19_TR1_movement.csv
# Saved geolabels to social_R20_TR1_geolabels.csv
# Saved movement to social_R20_TR1_movement.csv
# Saved geolabels to social_R21_TR1_geolabels.csv
# Saved movement to social_R21_TR1_movement.csv
# Saved geolabels to social_R22_TR1_geolabels.csv
# Saved movement to social_R22_TR1_movement.csv
# Saved geolabels to social_R23_TR1_geolabels.csv
# Saved movement to social_R23_TR1_movement.csv
# Saved geolabels to social_R01_TR2_geolabels.csv
# Saved movement to social_R01_TR2_movement.csv
# Saved geolabels to social_R02_TR2_geolabels.csv
# Saved movement to social_R02_TR2_movement.csv
# Saved geolabels to social_R03_TR2_geolabels.csv
# Saved movement to social_R03_TR2_movement.csv
# Saved geolabels to social_R04_TR2_geolabels.csv
# Saved movement to social_R04_TR2_movement.csv
# Saved geolabels to social_R05_TR2_geolabels.csv
# Saved movement to social_R05_TR2_movement.csv
# Saved geolabels to social_R06_TR2_geolabels.csv
# Saved movement to social_R06_TR2_movement.csv
# Saved geolabels to social_R07_TR2_geolabels.csv
# Saved movement to social_R07_TR2_movement.csv
# Saved geolabels to social_R08_TR2_geolabels.csv
# Saved movement to social_R08_TR2_movement.csv
# Saved geolabels to social_R09_TR2_geolabels.csv
# Saved movement to social_R09_TR2_movement.csv
# Saved geolabels to social_R10_TR2_geolabels.csv
# Saved movement to social_R10_TR2_movement.csv
# Saved geolabels to social_R11_TR2_geolabels.csv
# Saved movement to social_R11_TR2_movement.csv
# Saved geolabels to social_R12_TR2_geolabels.csv
# Saved movement to social_R12_TR2_movement.csv
# Saved geolabels to social_R13_TR2_geolabels.csv
# Saved movement to social_R13_TR2_movement.csv
# Saved geolabels to social_R14_TR2_geolabels.csv
# Saved movement to social_R14_TR2_movement.csv
# Saved geolabels to social_R15_TR2_geolabels.csv
# Saved movement to social_R15_TR2_movement.csv
# Saved geolabels to social_R16_TR2_geolabels.csv
# Saved movement to social_R16_TR2_movement.csv
# Saved geolabels to social_R17_TR2_geolabels.csv
# Saved movement to social_R17_TR2_movement.csv
# Saved geolabels to social_R18_TR2_geolabels.csv
# Saved movement to social_R18_TR2_movement.csv
# Saved geolabels to social_R19_TR2_geolabels.csv
# Saved movement to social_R19_TR2_movement.csv
# Saved geolabels to social_R20_TR2_geolabels.csv
# Saved movement to social_R20_TR2_movement.csv
# Saved geolabels to social_R21_TR2_geolabels.csv
# Saved movement to social_R21_TR2_movement.csv
# Saved geolabels to social_R22_TR2_geolabels.csv
# Saved movement to social_R22_TR2_movement.csv
# Saved geolabels to social_R23_TR2_geolabels.csv
# Saved movement to social_R23_TR2_movement.csv
# Saved geolabels to social_R02_TR3_geolabels.csv
# Saved movement to social_R02_TR3_movement.csv
# Saved geolabels to social_R03_TR3_geolabels.csv
# Saved movement to social_R03_TR3_movement.csv
# Saved geolabels to social_R05_TR3_geolabels.csv
# Saved movement to social_R05_TR3_movement.csv
# Saved geolabels to social_R06_TR3_geolabels.csv
# Saved movement to social_R06_TR3_movement.csv
# Saved geolabels to social_R08_TR3_geolabels.csv
# Saved movement to social_R08_TR3_movement.csv
# Saved geolabels to social_R09_TR3_geolabels.csv
# Saved movement to social_R09_TR3_movement.csv
# Saved geolabels to social_R11_TR3_geolabels.csv
# Saved movement to social_R11_TR3_movement.csv
# Saved geolabels to social_R13_TR3_geolabels.csv
# Saved movement to social_R13_TR3_movement.csv
# Saved geolabels to social_R14_TR3_geolabels.csv
# Saved movement to social_R14_TR3_movement.csv
# Saved geolabels to social_R15_TR3_geolabels.csv
# Saved movement to social_R15_TR3_movement.csv
# Saved geolabels to social_R17_TR3_geolabels.csv
# Saved movement to social_R17_TR3_movement.csv
# Saved geolabels to social_R18_TR3_geolabels.csv
# Saved movement to social_R18_TR3_movement.csv
# Saved geolabels to social_R19_TR3_geolabels.csv
# Saved movement to social_R19_TR3_movement.csv
# Saved geolabels to social_R20_TR3_geolabels.csv
# Saved movement to social_R20_TR3_movement.csv
# Saved geolabels to social_R23_TR3_geolabels.csv
# Saved movement to social_R23_TR3_movement.csv

# %% [markdown]
# ---
# ---
# #### Two new csv files were created for each video, one for exploration geolabels and the other for movement related scores.
# We can:
# - Move on to the next notebook to create an artificial neural network that labels exploratory behavior, ` 4-Create_models`.
# - Loose all patience, go straight to ` 6-Seize_labels` and use the geolabels to plot the results of the experiment.
#
# ---
# RAINSTORM - Created on Oct 26, 2023 - @author: Santiago D'hers
