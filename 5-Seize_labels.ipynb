# %% [markdown]
# RAINSTORM
#
# ## Seize labels
#
# - This notebook will help us visualize the results of labeled videos of an experiment
#
# #### Requirements:
#
# - The position.csv files processed by 1-Prepare_positions.ipynb
# - Geolabels, autolabels or manual labels for those same positions

# %% [markdown]
# ---
# #### Load the necessary modules

# %%
import os
import rainstorm.seize_labels as rst

# %% [markdown]
# ---
# #### 1. State your project path and experiment details
# `base` : The path to the downloaded repository.
#
# `groups` : Name the groups on your experiment.
#
# `trials` : Name the trials on your experiment.
#
# `objects` : Name the stationary objects that may appear on your data.
#
# `label_type` : State which labels you want to use. Options are `autolabels`, `geolabels`, or simply `labels` (for manual labels).
#
# `fps` : The frames per second of the video.

# %%
# State your path:
base = r'C:\Users\dhers\Desktop\Rainstorm'
folder_path = r'C:\Users\dhers\Desktop\SP_6mth'
params = os.path.join(folder_path, 'params.yaml')

# data = {group: {trial: objects for trial in trials} for group in groups}

# %% [markdown]
# ---
# #### 2. With the experiment details ready, we can create a reference file on our experiment folder.
# We need to complete and use the reference file to tell the functions which groups and objects to use for each mouse.

# %%
# Lets create the reference.csv file
reference_path = rst.create_reference_file(params)
# Out:
# Reference file already exists

# %% [markdown]
# #### Go to the experiment folder and complete the 'reference.csv' file
# If you are using the NOR_example folder to try out rainstorm, you will find a copy of the reference file **already completed** inside the 'h5 files & others' folder.
#
# All you need to do is move it to the experiment folder or copy its contents into the 'reference.csv' file.
#
# Once you have completed the reference file, you can proceed to the next step where we will use it to create the 'summary' folder.

# %% [markdown]
# ---
# #### 3. Create the 'Summary' folder
# This new folder will contain files for each video recording, which will be used to hold all the labels and geometric information.
#
# The groups and objects on the ‘reference’ file will be used to organize the files into subfolders, and the object exploration columns will be renamed according to their role (e.g. Novel and Known).

# %%
# Lets rename the labels
summary_path = rst.create_summary(params)
# Out:
# summary folder already exists
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R01-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R02-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R03-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R04-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R05-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R06-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R07-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R08-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R09-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R10-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R11-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R12-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R13-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R14-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R15-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R16-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R17-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R18-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\Hab\2025_02-R19-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\Hab\2025_02-R20-Social_Hab_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT
summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\WT\TR3\2025_02-R20-Social_TR3_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\SP_6mth\summary\3xTg\TR3\2025_02-R23-Social_TR3_summary.csv

# %% [markdown]
# ---
# #### 4. With our files ready, all is left to do is to run the analysis and plot the results.
#
# We can plot distance traveled, exploration for each object, freezing time, and more!

# %%
rst.plot_multiple_analyses(params, trial='Hab', plots=[rst.plot_exploration_time, rst.plot_exploration_boxplot, rst.plot_DI, rst.plot_exploration_scatterplot])
rst.plot_multiple_analyses(params, trial='TR1', plots=[rst.plot_exploration_time, rst.plot_exploration_boxplot, rst.plot_DI, rst.plot_exploration_scatterplot])
rst.plot_multiple_analyses(params, trial='TR2', plots=[rst.plot_exploration_time, rst.plot_exploration_boxplot, rst.plot_DI, rst.plot_exploration_scatterplot])
rst.plot_multiple_analyses(params, trial='TR3', plots=[rst.plot_exploration_time, rst.plot_exploration_boxplot, rst.plot_DI, rst.plot_exploration_scatterplot])
# Out:
# {'Hab': ['Left', 'Right'], 'TR1': ['Mice', 'Object'], 'TR2': ['Novel', 'Known'], 'TR3': ['Homecage', 'Known']}
# Plot saved at: C:\Users\dhers\Desktop\SP_6mth\plots\Hab_multiple_analyses.png
# {'Hab': ['Left', 'Right'], 'TR1': ['Mice', 'Object'], 'TR2': ['Novel', 'Known'], 'TR3': ['Homecage', 'Known']}
# Plot saved at: C:\Users\dhers\Desktop\SP_6mth\plots\TR1_multiple_analyses.png
# {'Hab': ['Left', 'Right'], 'TR1': ['Mice', 'Object'], 'TR2': ['Novel', 'Known'], 'TR3': ['Homecage', 'Known']}
# Plot saved at: C:\Users\dhers\Desktop\SP_6mth\plots\TR2_multiple_analyses.png
# {'Hab': ['Left', 'Right'], 'TR1': ['Mice', 'Object'], 'TR2': ['Novel', 'Known'], 'TR3': ['Homecage', 'Known']}
# Plot saved at: C:\Users\dhers\Desktop\SP_6mth\plots\TR3_multiple_analyses.png

# %% [markdown]
# ---
# #### 5. Plot each mouse individually
#
# After some user feedback, we decided to create plots for each mouse individually. This gives us the chance to evaluate if something is off, and spot any outliers on both training and testing sessions.
#
# This feature is not yet fully implemented, as it only works properly if we have two objects on the arena. We will add support for more (or none) objects in the future.
#
# You can test it with the demo data without problems, the plots will be stored in the example folder.

# %%
rst.plot_all(folder_path, data, groups, trials = ['TS', 'TR'], show=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 rst.plot_all(folder_path, data, groups, trials = ['TS', 'TR'], show=False)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ---
# ---
# #### These modular graphs are intended to show the dynamic behavior of mice, providing a deeper insight into what happens during learning and memory.
#
# We have reached the end of this project. If you have read and followed the code up to this point, I want to thank you for your time and attention. If you have any questions and/or suggestions, do not hesitate to write me: sdhers@fbmc.fcen.uba.ar
#
#
# ---
# RAINSTORM - Created on Jun 25, 2024 - @author: Santiago D'hers
