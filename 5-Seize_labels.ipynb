# %% [markdown]
# RAINSTORM
#
# ## Seize labels
#
# - This notebook will help us visualize the results of labeled videos of an experiment
#
# #### Requirements:
#
# - The position.csv files processed by 1-Prepare_positions.ipynb
# - Geolabels, autolabels or manual labels for those same positions

# %% [markdown]
# ---
# #### Load the necessary modules

# %%
import os
import rainstorm.seize_labels as rst

# %% [markdown]
# ---
# #### 1. State your project path and experiment details
# `base` : The path to the downloaded repository.
#
# `groups` : Name the groups on your experiment.
#
# `trials` : Name the trials on your experiment.
#
# `objects` : Name the stationary objects that may appear on your data.
#
# `label_type` : State which labels you want to use. Options are `autolabels`, `geolabels`, or simply `labels` (for manual labels).
#
# `fps` : The frames per second of the video.

# %%
# State your path:
base = r'C:\Users\dhers\Desktop\Rainstorm'
folder_path = os.path.join(base, r'docs\examples\NOR_example')

groups = ['24 hs', '1 week']
trials = ['TS', 'TR', 'Hab']
objects = ['obj_1', 'obj_2']

label_type = 'autolabels'
fps = 25

data = {group: {trial: objects for trial in trials} for group in groups}
data
# Out:
# {'24 hs': {'TS': ['obj_1', 'obj_2'],
#   'TR': ['obj_1', 'obj_2'],
#   'Hab': ['obj_1', 'obj_2']},
#  '1 week': {'TS': ['obj_1', 'obj_2'],
#   'TR': ['obj_1', 'obj_2'],
#   'Hab': ['obj_1', 'obj_2']}}

# %% [markdown]
# #### Copy the data dictionary and paste it below, changing the objects for their novelty (eg: ['Novel', 'Known'], ['Left', 'Right'] or None)

# %%
data = {
 '24 hs': {'TS': ['Novel', 'Known'],
  'TR': ['Left', 'Right'],
  'Hab': None},
 '1 week': {'TS': ['Novel', 'Known'],
  'TR': ['Left', 'Right'],
  'Hab': None},
  }

# %% [markdown]
# ---
# #### 2. With the experiment details ready, we can create a reference file on our experiment folder.
# We need to complete and use the reference file to tell the functions which groups and objects to use for each mouse.

# %%
# Lets create the reference.csv file
reference_path = rst.create_reference_file(folder_path, trials, objects)
# Out:
# CSV file 'C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\reference.csv' created successfully with the list of video files.

# %% [markdown]
# ---
# #### 3. Go to the experiment folder and complete the 'reference.csv' file
# If you are using the NOR_example folder to try out rainstorm, you will find a copy of the reference file **already completed** inside the 'h5 files & others' folder.
#
# All you need to do is move it to the experiment folder or copy its contents into the 'reference.csv' file.
#
# Once you have completed the reference file, you can proceed to the next step where we will use it to create the 'summary' folder.

# %%
# Lets rename the labels
summary_path = rst.create_summary(reference_path, label_type, trials, objects, fps)
# Out:
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C1_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C1_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C1_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C1_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C2_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C2_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C2_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C2_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C3_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C3_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C3_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C3_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C4_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C4_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C4_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C4_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C5_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TS\NOR_TS_C5_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C5_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TS\NOR_TS_C5_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C1_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C1_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C1_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C1_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C2_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C2_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C2_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C2_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C3_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C3_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C3_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C3_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C4_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C4_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C4_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C4_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C5_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\TR\NOR_TR_C5_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C5_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\TR\NOR_TR_C5_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C1_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C1_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C1_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C1_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C2_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C2_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C2_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C2_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C3_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C3_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C3_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C3_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C4_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C4_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C4_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C4_D_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C5_A_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\1 week\Hab\NOR_Hab_C5_B_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C5_C_summary.csv
# Renamed and saved: C:\Users\dhers\Desktop\Rainstorm\docs\examples\NOR_example\summary\24 hs\Hab\NOR_Hab_C5_D_summary.csv

# %% [markdown]
# ---
# #### 4. With our files ready, all is left to do is to run the analysis and plot the results.
#
# We can plot distance traveled, exploration for each object, freezing time, and more!

# %%
rst.plot_multiple_analyses(folder_path, data, groups, 'TS', [rst.plot_exploration_time, rst.plot_exploration_boxplot, rst.plot_DI], fps)
rst.plot_multiple_analyses(folder_path, data, groups, 'TR', [rst.plot_exploration_time, rst.plot_exploration_boxplot, rst.plot_DI], fps)
rst.plot_multiple_analyses(folder_path, data, groups, 'Hab', [rst.plot_distance, rst.plot_freezing], fps)

# %% [markdown]
# ---
# ---
# #### These modular graphs are intended to show the dynamic behavior of mice, providing a deeper insight into what happens with learning and memory.
#
# We have reached the end of this project. If you have read and followed the code up to this point, I want to thank you for your time and attention. If you have any questions and/or suggestions, do not hesitate to write me: sdhers@fbmc.fcen.uba.ar
#
#
# ---
# RAINSTORM - Created on Jun 25, 2024 - @author: Santiago D'hers
