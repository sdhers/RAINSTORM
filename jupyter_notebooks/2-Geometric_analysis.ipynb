# %% [markdown]
# RAINSTORM - Created on Oct 26, 2023 - @author: Santiago D'hers
#
# ### Geometric analysis
# - This notebook will take the position.csv files (created using 1-Prepare_positions) and process them using geometric criteria (distance, angle and overall movement).
#
# #### Requirements:
# - The position.csv files.
# - Geometric thresholds for exploration and freezing (see below).

# %% [markdown]
# ---
# #### 1. Load the necessary modules

# %%
import os
from glob import glob
import rainstorm.geometric_analysis as rst

# %% [markdown]
# ---
# #### 2. State your project path & thresholds
# `base` : The path to the downloaded repository. If you are using a Windows path with backslashes, place an ‘r’ in front of the directory path to avoid an error (e.g. r'C:\Users\dhers\Desktop\RAINSTORM').
#
# `filter_by` : A word that will be used to filter the position file used as an example.
#
# `objects` : Name the stationary objects that may appear on your data.
#
# `distance` : Maximum nose-object distance to consider exploration.
#
# `angle` : Maximum head-object orientation angle to consider exploration.
#
# `freezing_threshold` : Movement under which we consider freezing, calculated as the mean standard deviation for all bodyparts over one second.
#
# `darting_threshold` : Movement over which we consider darting, calculated as the mean standard deviation for all bodyparts over one second.
#
# `video_fps` : State the frames per second of the videos.

# %%
# State your path:
base = r'C:\Users\dhers\Desktop\RAINSTORM'
folder_path = os.path.join(base, 'docs\examples\position_files_copy')

all_position = glob(os.path.join(folder_path,"*/position/*position.csv"))
filter_by = 'TS'

# Set the parameters to evaluate behaviours
objects = ['obj_1', 'obj_2']
distance = 2.5 # in cm
angle = 45 # in degrees
freezing_threshold = 0.01
darting_threshold = 0.8

video_fps = 25

# %% [markdown]
# ---
# #### 3. We can open an example file and see what is inside

# %%
# Choose an example file to plot:
example_path = rst.choose_example(all_position, filter_by)
# Out:
# Plotting coordinates from 2024-09_NOR_TS_C4_C_position.csv

# %%
# Plot mouse exploration around multiple objects
rst.plot_position(example_path, objects = objects, maxDistance = distance, maxAngle = angle)

# %% [markdown]
# On the plot we have the position of each object in the example file. We can see the nose tracked and colored according to the angle of approach towards the objects.
#
# We label exploration events when the nose is colored (heading towards the object) and inside the dashed line (close to the object).

# %% [markdown]
# ---
# #### 4.  We can also measure other behaviours, such as freezing

# %%
# Plot freezing events
rst.plot_freezing(example_path, fps = video_fps, threshold=freezing_threshold)

# %% [markdown]
# Now we are plotting the movement of the mouse. by setting a threshold (we can modify it above) we can quantify the time the mouse spent freezing.

# %% [markdown]
# ---
# #### 5. Finally, we can analyze the position files and create:
# - A movement.csv file containing distance traveled, freezing and darting.
# - A geolabels.csv file with the exploration of each object, frame by frame.

# %%
# Analyze all files in the folder
rst.create_movement_and_geolabels(all_position, objects, maxDistance = distance, maxAngle = angle, fps = video_fps, freezing_thr = freezing_threshold, darting_thr = darting_threshold)
# Out:
# 2024-09_NOR_Hab_C1_A_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C1_A_movement.csv
# 2024-09_NOR_Hab_C1_B_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C1_B_movement.csv
# 2024-09_NOR_Hab_C1_C_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C1_C_movement.csv
# 2024-09_NOR_Hab_C2_A_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C2_A_movement.csv
# 2024-09_NOR_Hab_C2_B_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C2_B_movement.csv
# 2024-09_NOR_Hab_C2_C_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C2_C_movement.csv
# 2024-09_NOR_Hab_C3_A_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C3_A_movement.csv
# 2024-09_NOR_Hab_C3_B_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C3_B_movement.csv
# 2024-09_NOR_Hab_C3_C_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C3_C_movement.csv
# 2024-09_NOR_Hab_C4_A_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C4_A_movement.csv
# 2024-09_NOR_Hab_C4_B_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C4_B_movement.csv
# 2024-09_NOR_Hab_C4_C_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C4_C_movement.csv
# 2024-09_NOR_Hab_C5_A_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C5_A_movement.csv
# 2024-09_NOR_Hab_C5_B_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C5_B_movement.csv
# 2024-09_NOR_Hab_C5_C_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C5_C_movement.csv
# 2024-09_NOR_Hab_C6_A_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C6_A_movement.csv
# 2024-09_NOR_Hab_C6_B_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C6_B_movement.csv
# 2024-09_NOR_Hab_C6_C_position.csv is missing objects: obj_1, obj_2
# Saved movement to 2024-09_NOR_Hab_C6_C_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C1_A_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C1_A_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C1_B_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C1_B_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C1_C_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C1_C_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C2_A_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C2_A_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C2_B_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C2_B_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C2_C_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C2_C_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C3_A_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C3_A_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C3_B_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C3_B_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C3_C_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C3_C_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C4_A_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C4_A_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C4_B_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C4_B_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C4_C_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C4_C_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C5_A_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C5_A_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C5_B_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C5_B_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C5_C_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C5_C_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C6_A_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C6_A_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C6_B_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C6_B_movement.csv
# Saved geolabels to 2024-09_NOR_TR_C6_C_geolabels.csv
# Saved movement to 2024-09_NOR_TR_C6_C_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C1_A_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C1_A_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C1_B_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C1_B_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C1_C_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C1_C_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C2_A_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C2_A_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C2_B_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C2_B_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C2_C_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C2_C_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C3_A_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C3_A_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C3_B_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C3_B_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C3_C_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C3_C_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C4_A_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C4_A_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C4_B_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C4_B_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C4_C_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C4_C_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C5_A_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C5_A_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C5_B_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C5_B_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C5_C_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C5_C_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C6_A_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C6_A_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C6_B_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C6_B_movement.csv
# Saved geolabels to 2024-09_NOR_TS_C6_C_geolabels.csv
# Saved movement to 2024-09_NOR_TS_C6_C_movement.csv
